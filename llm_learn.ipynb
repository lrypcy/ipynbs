# %%
from transformers import pipeline
from tqdm.notebook import tqdm

# %%
ppl = pipeline(task="text-generation", model="Mxode/minicoder-7M-base", trust_remote_code=True, batch_size=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 ppl = pipeline(task="text-generation", model="Mxode/minicoder-7M-base", trust_remote_code=True, batch_size=2)
#
# NameError: name 'pipeline' is not defined

# %%
ppl(["hello my name is ", "jldaflsajflasjkfla", "lfjashelloworld"])
# Out:
# /Users/congyuan/Software/miniconda3/envs/torch/lib/python3.11/site-packages/transformers/generation/utils.py:1258: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# [[{'generated_text': 'hello my name is via them.\n       '}],
#  [{'generated_text': 'jldaflsajflasjkflags", "cfl'}],
#  [{'generated_text': 'lfjashelloworld_fraction_fraction_f'}]]

# %%
import sys
print("Python version:", sys.version)
